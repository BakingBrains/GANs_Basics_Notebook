# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.datasets as datasets
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
from torch.utils.tensorboard import SummaryWriter

# %%
class Discriminator(nn.Module):
    def __init__(self, channels_img, features_d):
        super(Discriminator, self).__init__()
        self.disc = nn.Sequential(
            # input: N x channels_img x 64 x 64
            nn.Conv2d(
                channels_img, features_d, kernel_size=4, stride=2, padding=1
            ),
            nn.LeakyReLU(0.2),
            # _block(in_channels, out_channels, kernel_size, stride, padding)
            self._block(features_d, features_d * 2, 4, 2, 1),
            self._block(features_d * 2, features_d * 4, 4, 2, 1),
            self._block(features_d * 4, features_d * 8, 4, 2, 1),
            # After all _block img output is 4x4 (Conv2d below makes into 1x1)
            nn.Conv2d(features_d * 8, 1, kernel_size=4, stride=2, padding=0),
            nn.Sigmoid(),
        )

    def _block(self, in_channels, out_channels, kernel_size, stride, padding):
        return nn.Sequential(
            nn.Conv2d(
                in_channels,
                out_channels,
                kernel_size,
                stride,
                padding,
                bias=False,
            ),
            #nn.BatchNorm2d(out_channels),
            nn.LeakyReLU(0.2),
        )

    def forward(self, x):
        return self.disc(x)

# %%
class Generator(nn.Module):
    def __init__(self, channels_noise, channels_img, features_g):
        super(Generator, self).__init__()
        self.net = nn.Sequential(
            # Input: N x channels_noise x 1 x 1
            self._block(channels_noise, features_g * 16, 4, 1, 0),  # img: 4x4
            self._block(features_g * 16, features_g * 8, 4, 2, 1),  # img: 8x8
            self._block(features_g * 8, features_g * 4, 4, 2, 1),  # img: 16x16
            self._block(features_g * 4, features_g * 2, 4, 2, 1),  # img: 32x32
            nn.ConvTranspose2d(
                features_g * 2, channels_img, kernel_size=4, stride=2, padding=1
            ),
            # Output: N x channels_img x 64 x 64
            nn.Tanh(),
        )

    def _block(self, in_channels, out_channels, kernel_size, stride, padding):
        return nn.Sequential(
            nn.ConvTranspose2d(
                in_channels,
                out_channels,
                kernel_size,
                stride,
                padding,
                bias=False,
            ),
            #nn.BatchNorm2d(out_channels),
            nn.ReLU(),
        )

    def forward(self, x):
        return self.net(x)

# %%
def initialize_weights(model):
    for m in model.modules():
        if isinstance(m, (nn.Conv2d, nn.ConvTranspose2d, nn.BatchNorm2d)):
            nn.init.normal_(m.weight.data, 0.0, 0.02)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
LEARNING_RATE = 2e-4  # could also use two lrs, one for gen and one for disc
BATCH_SIZE = 128
IMAGE_SIZE = 64
CHANNELS_IMG = 1
NOISE_DIM = 100
NUM_EPOCHS = 50
FEATURES_DISC = 64
FEATURES_GEN = 64

# %%
transforms = transforms.Compose(
    [
        transforms.Resize(IMAGE_SIZE),
        transforms.ToTensor(),
        transforms.Normalize(
            [0.5 for _ in range(CHANNELS_IMG)], [0.5 for _ in range(CHANNELS_IMG)]
        ),
    ]
)

# %%
# If you train on MNIST, remember to set channels_img to 1
dataset = datasets.MNIST(root="dataset/", train=True, transform=transforms,
                       download=True)

# comment mnist above and uncomment below if train on CelebA
#dataset = datasets.ImageFolder(root="celeb_dataset", transform=transforms)
dataloader = DataLoader(dataset, batch_size=BATCH_SIZE, shuffle=True)
gen = Generator(NOISE_DIM, CHANNELS_IMG, FEATURES_GEN).to(device)
disc = Discriminator(CHANNELS_IMG, FEATURES_DISC).to(device)
initialize_weights(gen)
initialize_weights(disc)

# %%
opt_gen = optim.Adam(gen.parameters(), lr=LEARNING_RATE, betas=(0.5, 0.999))
opt_disc = optim.Adam(disc.parameters(), lr=LEARNING_RATE, betas=(0.5, 0.999))
criterion = nn.BCELoss()

fixed_noise = torch.randn(32, NOISE_DIM, 1, 1).to(device)
writer_real = SummaryWriter(f"logs/real")
writer_fake = SummaryWriter(f"logs/fake")
step = 0

gen.train()
disc.train()
# Out:
# Discriminator(
#   (disc): Sequential(
#     (0): Conv2d(1, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (1): LeakyReLU(negative_slope=0.2)
#     (2): Sequential(
#       (0): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): LeakyReLU(negative_slope=0.2)
#     )
#     (3): Sequential(
#       (0): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): LeakyReLU(negative_slope=0.2)
#     )
#     (4): Sequential(
#       (0): Conv2d(256, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): LeakyReLU(negative_slope=0.2)
#     )
#     (5): Conv2d(512, 1, kernel_size=(4, 4), stride=(2, 2))
#     (6): Sigmoid()
#   )
# )

# %%
for epoch in range(NUM_EPOCHS):
    # Target labels not needed! <3 unsupervised
    for batch_idx, (real, _) in enumerate(dataloader):
        real = real.to(device)
        noise = torch.randn(BATCH_SIZE, NOISE_DIM, 1, 1).to(device)
        fake = gen(noise)

        ### Train Discriminator: max log(D(x)) + log(1 - D(G(z)))
        disc_real = disc(real).reshape(-1)
        loss_disc_real = criterion(disc_real, torch.ones_like(disc_real))
        disc_fake = disc(fake.detach()).reshape(-1)
        loss_disc_fake = criterion(disc_fake, torch.zeros_like(disc_fake))
        loss_disc = (loss_disc_real + loss_disc_fake) / 2
        disc.zero_grad()
        loss_disc.backward()
        opt_disc.step()

        ### Train Generator: min log(1 - D(G(z))) <-> max log(D(G(z))
        output = disc(fake).reshape(-1)
        loss_gen = criterion(output, torch.ones_like(output))
        gen.zero_grad()
        loss_gen.backward()
        opt_gen.step()

        # Print losses occasionally and print to tensorboard
        if batch_idx % 100 == 0:
            print(
                f"Epoch [{epoch}/{NUM_EPOCHS}] Batch {batch_idx}/{len(dataloader)} \
                  Loss D: {loss_disc:.4f}, loss G: {loss_gen:.4f}"
            )

            with torch.no_grad():
                fake = gen(fixed_noise)
                # take out (up to) 32 examples
                img_grid_real = torchvision.utils.make_grid(
                    real[:32], normalize=True
                )
                img_grid_fake = torchvision.utils.make_grid(
                    fake[:32], normalize=True
                )

                writer_real.add_image("Real", img_grid_real, global_step=step)
                writer_fake.add_image("Fake", img_grid_fake, global_step=step)

            step += 1
# Out:
# Epoch [0/50] Batch 0/469                   Loss D: 0.6924, loss G: 0.7673
# Epoch [0/50] Batch 100/469                   Loss D: 0.0002, loss G: 7.9629
# Epoch [0/50] Batch 200/469                   Loss D: 0.0001, loss G: 9.4338
# Epoch [0/50] Batch 300/469                   Loss D: 0.0001, loss G: 10.3011
# Epoch [0/50] Batch 400/469                   Loss D: 0.0000, loss G: 10.7382
# Epoch [1/50] Batch 0/469                   Loss D: 0.0000, loss G: 10.5001
# Epoch [1/50] Batch 100/469                   Loss D: 0.0000, loss G: 11.5838
# Epoch [1/50] Batch 200/469                   Loss D: 0.0000, loss G: 11.5910
# Epoch [1/50] Batch 300/469                   Loss D: 0.0000, loss G: 11.9926
# Epoch [1/50] Batch 400/469                   Loss D: 0.0000, loss G: 12.3669
# Epoch [2/50] Batch 0/469                   Loss D: 0.0000, loss G: 12.5701
# Epoch [2/50] Batch 100/469                   Loss D: 0.0000, loss G: 12.7389
# Epoch [2/50] Batch 200/469                   Loss D: 0.0000, loss G: 12.7126
# Epoch [2/50] Batch 300/469                   Loss D: 0.0000, loss G: 12.9308
# Epoch [2/50] Batch 400/469                   Loss D: 0.0000, loss G: 13.1965
# Epoch [3/50] Batch 0/469                   Loss D: 0.0000, loss G: 13.3439
# Epoch [3/50] Batch 100/469                   Loss D: 0.0000, loss G: 13.3449
# Epoch [3/50] Batch 200/469                   Loss D: 0.0000, loss G: 13.7295
# Epoch [3/50] Batch 300/469                   Loss D: 0.0000, loss G: 13.3741
# Epoch [3/50] Batch 400/469                   Loss D: 0.0000, loss G: 13.7961
# Epoch [4/50] Batch 0/469                   Loss D: 0.0000, loss G: 13.7280
# Epoch [4/50] Batch 100/469                   Loss D: 0.0000, loss G: 13.6381
# Epoch [4/50] Batch 200/469                   Loss D: 0.0000, loss G: 14.0934
# Epoch [4/50] Batch 300/469                   Loss D: 0.0000, loss G: 14.2197
# Epoch [4/50] Batch 400/469                   Loss D: 0.0000, loss G: 14.3192
# Epoch [5/50] Batch 0/469                   Loss D: 0.0000, loss G: 14.4159
# Epoch [5/50] Batch 100/469                   Loss D: 0.0000, loss G: 13.1914
# Epoch [5/50] Batch 200/469                   Loss D: 0.0000, loss G: 14.3074
# Epoch [5/50] Batch 300/469                   Loss D: 0.0000, loss G: 14.7075
# Epoch [5/50] Batch 400/469                   Loss D: 0.0000, loss G: 14.7924
# Epoch [6/50] Batch 0/469                   Loss D: 0.0000, loss G: 14.9026
# Epoch [6/50] Batch 100/469                   Loss D: 0.0000, loss G: 14.9718
# Epoch [6/50] Batch 200/469                   Loss D: 0.0000, loss G: 15.1364
# Epoch [6/50] Batch 300/469                   Loss D: 0.0000, loss G: 14.8000
# Epoch [6/50] Batch 400/469                   Loss D: 0.0000, loss G: 15.1832
# Epoch [7/50] Batch 0/469                   Loss D: 0.0000, loss G: 15.3980
# Epoch [7/50] Batch 100/469                   Loss D: 0.0000, loss G: 15.2499
# Epoch [7/50] Batch 200/469                   Loss D: 0.0000, loss G: 13.4481
# Epoch [7/50] Batch 300/469                   Loss D: 0.0000, loss G: 15.5962
# Epoch [7/50] Batch 400/469                   Loss D: 0.0000, loss G: 15.7090
# Epoch [8/50] Batch 0/469                   Loss D: 0.0000, loss G: 14.3824
# Epoch [8/50] Batch 100/469                   Loss D: 0.0000, loss G: 15.8777
# Epoch [8/50] Batch 200/469                   Loss D: 0.0000, loss G: 14.6619
# Epoch [8/50] Batch 300/469                   Loss D: 0.0000, loss G: 15.9321
# Epoch [8/50] Batch 400/469                   Loss D: 0.0000, loss G: 15.8294
# Epoch [9/50] Batch 0/469                   Loss D: 0.0000, loss G: 15.9508
# Epoch [9/50] Batch 100/469                   Loss D: 0.0000, loss G: 16.1750
# Epoch [9/50] Batch 200/469                   Loss D: 0.0000, loss G: 15.9973
# Epoch [9/50] Batch 300/469                   Loss D: 0.0000, loss G: 16.0973
# Epoch [9/50] Batch 400/469                   Loss D: 0.0000, loss G: 15.8552
# Epoch [10/50] Batch 0/469                   Loss D: 0.0000, loss G: 16.3474
# Epoch [10/50] Batch 100/469                   Loss D: 0.0000, loss G: 16.3920
# Epoch [10/50] Batch 200/469                   Loss D: 0.0000, loss G: 16.5099
# Epoch [10/50] Batch 300/469                   Loss D: 0.0000, loss G: 14.5031
# Epoch [10/50] Batch 400/469                   Loss D: 0.0000, loss G: 16.6440
# Epoch [11/50] Batch 0/469                   Loss D: 0.0000, loss G: 16.5548
# Epoch [11/50] Batch 100/469                   Loss D: 0.0000, loss G: 16.7400
# Epoch [11/50] Batch 200/469                   Loss D: 0.0000, loss G: 16.7458
# Epoch [11/50] Batch 300/469                   Loss D: 0.0000, loss G: 16.8794
# Epoch [11/50] Batch 400/469                   Loss D: 0.0000, loss G: 16.4264
# Epoch [12/50] Batch 0/469                   Loss D: 0.0000, loss G: 16.9707
# Epoch [12/50] Batch 100/469                   Loss D: 0.0000, loss G: 16.7705
# Epoch [12/50] Batch 200/469                   Loss D: 0.0000, loss G: 17.1331
# Epoch [12/50] Batch 300/469                   Loss D: 0.0000, loss G: 17.2344
# Epoch [12/50] Batch 400/469                   Loss D: 0.0000, loss G: 16.8583
# Epoch [13/50] Batch 0/469                   Loss D: 0.0000, loss G: 17.2100
# Epoch [13/50] Batch 100/469                   Loss D: 0.0000, loss G: 17.1072
# Epoch [13/50] Batch 200/469                   Loss D: 0.0000, loss G: 17.4124
# Epoch [13/50] Batch 300/469                   Loss D: 0.0000, loss G: 17.4590
# Epoch [13/50] Batch 400/469                   Loss D: 0.0000, loss G: 17.3201
# Epoch [14/50] Batch 0/469                   Loss D: 0.0000, loss G: 16.8983
# Epoch [14/50] Batch 100/469                   Loss D: 0.0000, loss G: 16.7583
# Epoch [14/50] Batch 200/469                   Loss D: 0.0000, loss G: 17.5237
# Epoch [14/50] Batch 300/469                   Loss D: 0.0000, loss G: 17.2969
# Epoch [14/50] Batch 400/469                   Loss D: 0.0000, loss G: 17.7386
# Epoch [15/50] Batch 0/469                   Loss D: 0.0000, loss G: 17.8310
# Epoch [15/50] Batch 100/469                   Loss D: 0.0000, loss G: 17.9569
# Epoch [15/50] Batch 200/469                   Loss D: 0.0000, loss G: 18.0097
# Epoch [15/50] Batch 300/469                   Loss D: 0.0000, loss G: 18.0543
# Epoch [15/50] Batch 400/469                   Loss D: 0.0000, loss G: 17.9149
# Epoch [16/50] Batch 0/469                   Loss D: 0.0000, loss G: 17.9763
# Epoch [16/50] Batch 100/469                   Loss D: 0.0000, loss G: 18.1335
# Epoch [16/50] Batch 200/469                   Loss D: 0.0000, loss G: 17.4446
# Epoch [16/50] Batch 300/469                   Loss D: 0.0000, loss G: 18.1743
# Epoch [16/50] Batch 400/469                   Loss D: 0.0000, loss G: 18.3137
# Epoch [17/50] Batch 0/469                   Loss D: 0.0000, loss G: 18.3957
# Epoch [17/50] Batch 100/469                   Loss D: 0.0000, loss G: 18.2226
# Epoch [17/50] Batch 200/469                   Loss D: 0.0000, loss G: 18.2399
# Epoch [17/50] Batch 300/469                   Loss D: 0.0000, loss G: 18.5510
# Epoch [17/50] Batch 400/469                   Loss D: 0.0000, loss G: 18.6125
# Epoch [18/50] Batch 0/469                   Loss D: 0.0000, loss G: 18.3494
# Epoch [18/50] Batch 100/469                   Loss D: 0.0000, loss G: 18.7004
# Epoch [18/50] Batch 200/469                   Loss D: 0.0000, loss G: 18.7553
# Epoch [18/50] Batch 300/469                   Loss D: 0.0000, loss G: 18.8149
# Epoch [18/50] Batch 400/469                   Loss D: 0.0000, loss G: 18.8751
# Epoch [19/50] Batch 0/469                   Loss D: 0.0000, loss G: 17.5948
# Epoch [19/50] Batch 100/469                   Loss D: 0.0000, loss G: 18.7679
# Epoch [19/50] Batch 200/469                   Loss D: 0.0000, loss G: 18.3952
# Epoch [19/50] Batch 300/469                   Loss D: 0.0000, loss G: 17.9893
# Epoch [19/50] Batch 400/469                   Loss D: 0.0000, loss G: 18.8810
# Epoch [20/50] Batch 0/469                   Loss D: 0.0000, loss G: 18.5482
# Epoch [20/50] Batch 100/469                   Loss D: 0.0000, loss G: 19.2010
# Epoch [20/50] Batch 200/469                   Loss D: 0.0000, loss G: 19.3066
# Epoch [20/50] Batch 300/469                   Loss D: 0.0000, loss G: 18.1482
# Epoch [20/50] Batch 400/469                   Loss D: 0.0000, loss G: 19.3356
# Epoch [21/50] Batch 0/469                   Loss D: 0.0000, loss G: 19.3467
# Epoch [21/50] Batch 100/469                   Loss D: 0.0000, loss G: 18.2927
# Epoch [21/50] Batch 200/469                   Loss D: 0.0000, loss G: 19.5095
# Epoch [21/50] Batch 300/469                   Loss D: 0.0000, loss G: 19.6590
# Epoch [21/50] Batch 400/469                   Loss D: 0.0000, loss G: 18.9247
# Epoch [22/50] Batch 0/469                   Loss D: 0.0000, loss G: 19.1275
# Epoch [22/50] Batch 100/469                   Loss D: 0.0000, loss G: 19.6842
# Epoch [22/50] Batch 200/469                   Loss D: 0.0000, loss G: 19.8891
# Epoch [22/50] Batch 300/469                   Loss D: 0.0000, loss G: 19.2476
# Epoch [22/50] Batch 400/469                   Loss D: 0.0000, loss G: 19.9701
# Epoch [23/50] Batch 0/469                   Loss D: 0.0000, loss G: 19.0250
# Epoch [23/50] Batch 100/469                   Loss D: 0.0000, loss G: 20.1070
# Epoch [23/50] Batch 200/469                   Loss D: 0.0000, loss G: 20.1712
# Epoch [23/50] Batch 300/469                   Loss D: 0.0000, loss G: 18.8947
# Epoch [23/50] Batch 400/469                   Loss D: 0.0000, loss G: 19.6789
# Epoch [24/50] Batch 0/469                   Loss D: 0.0000, loss G: 20.2298
# Epoch [24/50] Batch 100/469                   Loss D: 0.0000, loss G: 20.1234
# Epoch [24/50] Batch 200/469                   Loss D: 0.0000, loss G: 20.0809
# Epoch [24/50] Batch 300/469                   Loss D: 0.0000, loss G: 20.4780
# Epoch [24/50] Batch 400/469                   Loss D: 0.0000, loss G: 20.5346
# Epoch [25/50] Batch 0/469                   Loss D: 0.0000, loss G: 20.5044
# Epoch [25/50] Batch 100/469                   Loss D: 0.0000, loss G: 20.6500
# Epoch [25/50] Batch 200/469                   Loss D: 0.0000, loss G: 20.1099
# Epoch [25/50] Batch 300/469                   Loss D: 0.0000, loss G: 19.9466
# Epoch [25/50] Batch 400/469                   Loss D: 0.0000, loss G: 20.7498
# Epoch [26/50] Batch 0/469                   Loss D: 0.0000, loss G: 20.7633
# Epoch [26/50] Batch 100/469                   Loss D: 0.0000, loss G: 18.6554
# Epoch [26/50] Batch 200/469                   Loss D: 0.0000, loss G: 20.8319
# Epoch [26/50] Batch 300/469                   Loss D: 0.0000, loss G: 20.9056
# Epoch [26/50] Batch 400/469                   Loss D: 0.0000, loss G: 21.0854
# Epoch [27/50] Batch 0/469                   Loss D: 0.0000, loss G: 21.1548
# Epoch [27/50] Batch 100/469                   Loss D: 0.0000, loss G: 20.9409
# Epoch [27/50] Batch 200/469                   Loss D: 0.0000, loss G: 20.3614
# Epoch [27/50] Batch 300/469                   Loss D: 0.0000, loss G: 21.3464
# Epoch [27/50] Batch 400/469                   Loss D: 0.0000, loss G: 21.3818
# Epoch [28/50] Batch 0/469                   Loss D: 0.0000, loss G: 20.8800
# Epoch [28/50] Batch 100/469                   Loss D: 0.0000, loss G: 19.9375
# Epoch [28/50] Batch 200/469                   Loss D: 0.0000, loss G: 21.5011
# Epoch [28/50] Batch 300/469                   Loss D: 0.0000, loss G: 21.4706
# Epoch [28/50] Batch 400/469                   Loss D: 0.0000, loss G: 21.6214
# Epoch [29/50] Batch 0/469                   Loss D: 0.0000, loss G: 21.6158
# Epoch [29/50] Batch 100/469                   Loss D: 0.0000, loss G: 21.3797
# Epoch [29/50] Batch 200/469                   Loss D: 0.0000, loss G: 21.3606
# Epoch [29/50] Batch 300/469                   Loss D: 0.0000, loss G: 21.6011
# Epoch [29/50] Batch 400/469                   Loss D: 0.0000, loss G: 21.7371
# Epoch [30/50] Batch 0/469                   Loss D: 0.0000, loss G: 20.8381
# Epoch [30/50] Batch 100/469                   Loss D: 0.0000, loss G: 21.8743
# Epoch [30/50] Batch 200/469                   Loss D: 0.0000, loss G: 21.6589
# Epoch [30/50] Batch 300/469                   Loss D: 0.0000, loss G: 21.9354
# Epoch [30/50] Batch 400/469                   Loss D: 0.0000, loss G: 21.8080
# Epoch [31/50] Batch 0/469                   Loss D: 0.0000, loss G: 21.7837
# Epoch [31/50] Batch 100/469                   Loss D: 0.0000, loss G: 21.7648
# Epoch [31/50] Batch 200/469                   Loss D: 0.0000, loss G: 21.7272
# Epoch [31/50] Batch 300/469                   Loss D: 0.0000, loss G: 22.1229
# Epoch [31/50] Batch 400/469                   Loss D: 0.0000, loss G: 22.1705
# Epoch [32/50] Batch 0/469                   Loss D: 0.0000, loss G: 22.1802
# Epoch [32/50] Batch 100/469                   Loss D: 0.0000, loss G: 22.3247
# Epoch [32/50] Batch 200/469                   Loss D: 0.0000, loss G: 21.1255
# Epoch [32/50] Batch 300/469                   Loss D: 0.0000, loss G: 22.0287
# Epoch [32/50] Batch 400/469                   Loss D: 0.0000, loss G: 22.5069
# Epoch [33/50] Batch 0/469                   Loss D: 0.0000, loss G: 20.8945
# Epoch [33/50] Batch 100/469                   Loss D: 0.0000, loss G: 20.4126
# Epoch [33/50] Batch 200/469                   Loss D: 0.0000, loss G: 22.4263
# Epoch [33/50] Batch 300/469                   Loss D: 0.0000, loss G: 22.5047
# Epoch [33/50] Batch 400/469                   Loss D: 0.0000, loss G: 22.6583
# Epoch [34/50] Batch 0/469                   Loss D: 0.0000, loss G: 22.6475
# Epoch [34/50] Batch 100/469                   Loss D: 0.0000, loss G: 22.8111
# Epoch [34/50] Batch 200/469                   Loss D: 0.0000, loss G: 20.4431
# Epoch [34/50] Batch 300/469                   Loss D: 0.0000, loss G: 22.6394
# Epoch [34/50] Batch 400/469                   Loss D: 0.0000, loss G: 22.9531
# Epoch [35/50] Batch 0/469                   Loss D: 0.0000, loss G: 22.8434
# Epoch [35/50] Batch 100/469                   Loss D: 0.0000, loss G: 21.8237
# Epoch [35/50] Batch 200/469                   Loss D: 0.0000, loss G: 23.0660
# Epoch [35/50] Batch 300/469                   Loss D: 0.0000, loss G: 22.9460
# Epoch [35/50] Batch 400/469                   Loss D: 0.0000, loss G: 23.1625
# Epoch [36/50] Batch 0/469                   Loss D: 0.0000, loss G: 23.0304
# Epoch [36/50] Batch 100/469                   Loss D: 0.0000, loss G: 23.1164
# Epoch [36/50] Batch 200/469                   Loss D: 0.0000, loss G: 23.2003
# Epoch [36/50] Batch 300/469                   Loss D: 0.0000, loss G: 23.3884
# Epoch [36/50] Batch 400/469                   Loss D: 0.0000, loss G: 22.7829
# Epoch [37/50] Batch 0/469                   Loss D: 0.0000, loss G: 23.2496
# Epoch [37/50] Batch 100/469                   Loss D: 0.0000, loss G: 23.3440
# Epoch [37/50] Batch 200/469                   Loss D: 0.0000, loss G: 21.5824
# Epoch [37/50] Batch 300/469                   Loss D: 0.0000, loss G: 22.5864
# Epoch [37/50] Batch 400/469                   Loss D: 0.0000, loss G: 23.5705
# Epoch [38/50] Batch 0/469                   Loss D: 0.0000, loss G: 23.6467
# Epoch [38/50] Batch 100/469                   Loss D: 0.0000, loss G: 23.1197
# Epoch [38/50] Batch 200/469                   Loss D: 0.0000, loss G: 22.7608
# Epoch [38/50] Batch 300/469                   Loss D: 0.0000, loss G: 23.2530
# Epoch [38/50] Batch 400/469                   Loss D: 0.0000, loss G: 23.6383
# Epoch [39/50] Batch 0/469                   Loss D: 0.0000, loss G: 23.7646
# Epoch [39/50] Batch 100/469                   Loss D: 0.0000, loss G: 23.4767
# Epoch [39/50] Batch 200/469                   Loss D: 0.0000, loss G: 23.5706
# Epoch [39/50] Batch 300/469                   Loss D: 0.0000, loss G: 23.7925
# Epoch [39/50] Batch 400/469                   Loss D: 0.0000, loss G: 23.6738
# Epoch [40/50] Batch 0/469                   Loss D: 0.0000, loss G: 23.9152
# Epoch [40/50] Batch 100/469                   Loss D: 0.0000, loss G: 22.8648
# Epoch [40/50] Batch 200/469                   Loss D: 0.0000, loss G: 22.7127
# Epoch [40/50] Batch 300/469                   Loss D: 0.0000, loss G: 23.9340
# Epoch [40/50] Batch 400/469                   Loss D: 0.0000, loss G: 24.1186
# Epoch [41/50] Batch 0/469                   Loss D: 0.0000, loss G: 24.2421
# Epoch [41/50] Batch 100/469                   Loss D: 0.0000, loss G: 23.7397
# Epoch [41/50] Batch 200/469                   Loss D: 0.0000, loss G: 23.9488
# Epoch [41/50] Batch 300/469                   Loss D: 0.0000, loss G: 24.2806
# Epoch [41/50] Batch 400/469                   Loss D: 0.0000, loss G: 23.5976
# Epoch [42/50] Batch 0/469                   Loss D: 0.0000, loss G: 24.2554
# Epoch [42/50] Batch 100/469                   Loss D: 0.0000, loss G: 24.1155
# Epoch [42/50] Batch 200/469                   Loss D: 0.0000, loss G: 24.1292
# Epoch [42/50] Batch 300/469                   Loss D: 0.0000, loss G: 24.3915
# Epoch [42/50] Batch 400/469                   Loss D: 0.0000, loss G: 23.8777
# Epoch [43/50] Batch 0/469                   Loss D: 0.0000, loss G: 24.0396
# Epoch [43/50] Batch 100/469                   Loss D: 0.0000, loss G: 23.6632
# Epoch [43/50] Batch 200/469                   Loss D: 0.0000, loss G: 24.4781
# Epoch [43/50] Batch 300/469                   Loss D: 0.0000, loss G: 24.3942
# Epoch [43/50] Batch 400/469                   Loss D: 0.0000, loss G: 24.6706
# Epoch [44/50] Batch 0/469                   Loss D: 0.0000, loss G: 23.8841
# Epoch [44/50] Batch 100/469                   Loss D: 0.0000, loss G: 24.2674
# Epoch [44/50] Batch 200/469                   Loss D: 0.0000, loss G: 24.2041
# Epoch [44/50] Batch 300/469                   Loss D: 0.0000, loss G: 24.6443
# Epoch [44/50] Batch 400/469                   Loss D: 0.0000, loss G: 24.8744
# Epoch [45/50] Batch 0/469                   Loss D: 0.0000, loss G: 24.4136
# Epoch [45/50] Batch 100/469                   Loss D: 0.0000, loss G: 23.1494
# Epoch [45/50] Batch 200/469                   Loss D: 0.0000, loss G: 24.7877
# Epoch [45/50] Batch 300/469                   Loss D: 0.0000, loss G: 24.6013
# Epoch [45/50] Batch 400/469                   Loss D: 0.0000, loss G: 24.4272
# Epoch [46/50] Batch 0/469                   Loss D: 0.0000, loss G: 24.5616
# Epoch [46/50] Batch 100/469                   Loss D: 0.0000, loss G: 24.7517
# Epoch [46/50] Batch 200/469                   Loss D: 0.0000, loss G: 24.6817
# Epoch [46/50] Batch 300/469                   Loss D: 0.0000, loss G: 24.9245
# Epoch [46/50] Batch 400/469                   Loss D: 0.0000, loss G: 25.0117
# Epoch [47/50] Batch 0/469                   Loss D: 0.0000, loss G: 25.1726
# Epoch [47/50] Batch 100/469                   Loss D: 0.0000, loss G: 23.9232
# Epoch [47/50] Batch 200/469                   Loss D: 0.0000, loss G: 25.0188
# Epoch [47/50] Batch 300/469                   Loss D: 0.0000, loss G: 25.0333

# %%
# %load_ext tensorboard
# %tensorboard --logdir logs
